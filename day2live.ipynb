# %% [markdown]
# <a href="https://colab.research.google.com/github/aeshapatel123/Live_session/blob/main/day2live.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# User Authentication

# %%
print("Enter a username")
name=input()
if(len(name)>6):
  print("Valid Username")
else:
  print("Invalid Username")
# Out:
# Enter a username
# aeshh12345gg05
# Valid Username

# %% [markdown]
# Daily Sales Analysis

# %%
sales=[1200,4000,5690,6700,8400,4500,6500]
total=0
for i in sales:
  total+=i
  maximum=max(sales)
print("Total sales of the week is :",total)
print("The Highest sale is : ",maximum)
# Out:
# Total sales of the week is : 36990
# The Highest sale is :  8400
